# %%
df.iloc

# %%
df.iloc[2:11]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.iloc[2:11]
#
# NameError: name 'df' is not defined

# %%
df.iloc[[3,5,9,11,15]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.iloc[[3,5,9,11,15]]
#
# NameError: name 'df' is not defined

# %%
df.iloc[[2,4,6],[2,3]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.iloc[[2,4,6],[2,3]]
#
# NameError: name 'df' is not defined

# %%
df=df.set_index(id)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df=df.set_index(id)
#       2 df
#
# NameError: name 'df' is not defined

# %%
df.loc[7129300520]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.loc[7129300520]
#
# NameError: name 'df' is not defined

# %% [markdown]
# # DATA CLEANING AND MANIPULATION
# remove row and column
# rename columns
# change datatype of a column
# dropping missing values
# handling mising values
# value counts in a column

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
df=df.drop(labels=[195440010])
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df=df.drop(labels=[195440010])
#       2 df
#
# NameError: name 'df' is not defined

# %%
rename={
    'lat' : 'latitude'
    'long' : 'longitude'
}
df=df.rename(columns=rename)
df.columns
# Out:
#   Cell In[11], line 3
#     'long' : 'longitude'
#            ^
# SyntaxError: invalid syntax

# %%
df=df['yr_built'].asstype(float)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df=df['yr_built'].asstype(float)
#
# NameError: name 'df' is not defined

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined
